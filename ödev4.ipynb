# %% [markdown]
# <a href="https://colab.research.google.com/github/ZeynepBeser/9Sinif-4Odev/blob/master/%C3%B6dev4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ödev 1**
#
#   Fermat'nın Küçük Teoremi:

# %%
print("p asal sayı ve n∈N ise") p|n^p-n

# %% [markdown]
# **Ödev 3**

# %%
n1=[]
for i in range (0,999):
  if(i%3==0) or (i%5==0):
    n1.append(str(i))
print(n1)
# Out:
# ['0', '3', '5', '6', '9', '10', '12', '15', '18', '20', '21', '24', '25', '27', '30', '33', '35', '36', '39', '40', '42', '45', '48', '50', '51', '54', '55', '57', '60', '63', '65', '66', '69', '70', '72', '75', '78', '80', '81', '84', '85', '87', '90', '93', '95', '96', '99', '100', '102', '105', '108', '110', '111', '114', '115', '117', '120', '123', '125', '126', '129', '130', '132', '135', '138', '140', '141', '144', '145', '147', '150', '153', '155', '156', '159', '160', '162', '165', '168', '170', '171', '174', '175', '177', '180', '183', '185', '186', '189', '190', '192', '195', '198', '200', '201', '204', '205', '207', '210', '213', '215', '216', '219', '220', '222', '225', '228', '230', '231', '234', '235', '237', '240', '243', '245', '246', '249', '250', '252', '255', '258', '260', '261', '264', '265', '267', '270', '273', '275', '276', '279', '280', '282', '285', '288', '290', '291', '294', '295', '297', '300', '303', '305', '306', '309', '310', '312', '315', '318', '320',
# ...

# %% [markdown]
# **Ödev 4**

# %%
def fib(n):
  a=0
  b=1

  if n==1:
    print(a)
  else:
    print(a)
    print(b)

    for i in range(2,n):
      c=a+b
      a=b
      b=c
      if c<=4000000:
        if c %2==0:
          print(c)

fib(4000000)
# Out:
# 0
# 1
# 2
# 8
# 34
# 144
# 610
# 2584
# 10946
# 46368
# 196418
# 832040
# 3524578
